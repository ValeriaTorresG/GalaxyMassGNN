# %% [markdown]
# # DESI EDR
#
# hdu -> Header Data Unit -> Estructura y metadata en ASCII
#
# LSS -> Large-Scale Structura
#
# fits -> 2880 bytes of 8 bits

# %%
from astropy.io import fits
from astropy.table import Table as t
from astropy.cosmology import WMAP9 as cosmo

from astropy.io import misc
import h5py

import numpy as np
import matplotlib.pyplot as plt

# %%
with fits.open('./data/BGS_BRIGHT_N_0_clustering.ran.fits') as hdu:
    table = t(hdu[1].data)

table
# Out:
# <Table length=215721>
#      TARGETID              RA         ...       WEIGHT_FKP
#       int64             float64       ...        float64
# ------------------ ------------------ ... ---------------------
# 327863312287006861   217.053993747975 ...   0.01149153305805754
# 327863312287006871 216.96105123277434 ...   0.09561734123289738
# 327863312287006915 217.05116530360402 ...   0.03826194249707034
# 327863312287006987  217.0442969494446 ...  0.017459485623234086
# 327863312287007608 217.05123979169434 ...   0.13371119385114222
# 327863312287007688 216.98216862256743 ... 0.0029186997834375608
# 327863312287007980 216.99280256908355 ... 0.0017445635962380836
# 327863312287008123  217.0097205677191 ...  0.007066106315277897
# 327863312287008353  217.0434195828927 ...  0.005921525235303553
# 327863312287008359 216.94778732912923 ...  0.035160847734210195
#                ...                ... ...                   ...
# 327863846674892879 270.45760404158284 ...  0.007104943156241312
# 327863846674892907  270.5202206214184 ...  0.007104943156241312
# 327863846674893037  270.6329155217185 ...    0.0122182687745007
# 327863846674893315  270.6540766049186 ...   0.09561734123289738
# 327863846674893321  270.6467010968857 ...   0.06867818347743217
# 327863846674893364  270.6784787549827 ...  0.035160847734210195
# 327863846674893425  270.4423925352603 ...  0.005921525235303553
# 327863846674893525  270.3544169603379 ...   0.03826194249707034
# 327863846674893695  270.4952224471177 ... 0.0030775738791196166
# 327863846674893766  270.4453921010364 ...   0.06867818347743217

# %%
hdu.info() #* Es una tabla binaria
# Out:
# Filename: ./data/BGS_BRIGHT_N_0_clustering.ran.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  LSS           1 BinTableHDU     73   215721R x 26C   [K, D, D, K, 43A, J, D, D, D, D, E, E, E, E, E, D, D, D, D, D, D, D, D, D, D, D]

# %%
hdu[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  219 / length of dimension 1
# NAXIS2  =               215721 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   26 / number of table fields
# TTYPE1  = 'TARGETID'
# TFORM1  = 'K       '
# TTYPE2  = 'RA      '
# TFORM2  = 'D       '
# TUNIT2  = 'deg     '
# TTYPE3  = 'DEC     '
# TFORM3  = 'D       '
# TUNIT3  = 'deg     '
# TTYPE4  = 'NTILE   '
# TFORM4  = 'K       '
# TTYPE5  = 'TILES   '
# TFORM5  = '43A     '
# TTYPE6  = 'ROSETTE_NUMBER'
# TFORM6  = 'J       '
# TTYPE7  = 'ROSETTE_R'
# TFORM7  = 'D       '
# TUNIT7  = 'deg     '
# TTYPE8  = 'COMP_TILE'
# TFORM8  = 'D       '
# TTYPE9  = 'Z       '
# TFORM9  = 'D       '
# TTYPE10 = 'WEIGHT  '
# TFORM10 = 'D       '
# TTYPE11 = 'FLUX_G_DERED'
# TFORM11 = 'E       '
# TUNIT11 = 'nanomaggy'
# TTYPE12 = 'FLUX_R_DERED'
# TFORM12 = 'E       '
# TUNIT12 = 'nanomaggy'
# TTYPE13 = 'FLUX_Z_DERED'
# TFORM13 = 'E       '
# TUNIT13 = 'nanomaggy'
# TTYPE14 = 'FLUX_W1_DERED'
# TFORM14 = 'E       '
# TUNIT14 = 'nanomaggy'
# TTYPE15 = 'FLUX_W2_DERED'
# TFORM15 = 'E       '
# TUNIT15 = 'nanomaggy'
# TTYPE16 = 'REST_GMR_0P1'
# TFORM16 = 'D       '
# TTYPE17 = 'KCORR_R0P1'
# TFORM17 = 'D       '
# TTYPE18 = 'KCORR_G0P1'
# TFORM18 = 'D       '
# TTYPE19 = 'KCORR_R0P0'
# TFORM19 = 'D       '
# TTYPE20 = 'KCORR_G0P0'
# TFORM20 = 'D       '
# TTYPE21 = 'REST_GMR_0P0'
# TFORM21 = 'D       '
# TTYPE22 = 'EQ_ALL_0P0'
# TFORM22 = 'D       '
# TTYPE23 = 'EQ_ALL_0P1'
# TFORM23 = 'D       '
# TTYPE24 = 'ABSMAG_R'
# TFORM24 = 'D       '
# TTYPE25 = 'NZ      '
# TFORM25 = 'D       '
# TUNIT25 = 'h^3 Mpc^-3'
# TTYPE26 = 'WEIGHT_FKP'
# TFORM26 = 'D       '
# EXTNAME = 'LSS     '
# DESIDR  = 'edr     '
# COMMENT Visit https://desidatamodel.readthedocs.io/en/latest/ for a more complet
# COMMENT e description

# %%
hdu = fits.open('./data/BGS_BRIGHT_N_0_clustering.ran.fits')
data = hdu[1].data #! Lo tengo que abrir otra vez para que no salga error ???
data
# Out:
# FITS_rec([(327863312287006861, 217.05399375, 32.84433958, 2, '208-211',  7, 1.67508738, 1.        , 0.18115679, 1.01574803,  6.6309824, 18.932077, 35.924744, 29.712479, 19.276299, 0.91369751,  0.00123333,  0.22658534, 0.22804681, 0.6059797 , 0.76111664, -0.17572209, -0.07872209, -19.63247621, 0.01270769, 0.01149153),
#           (327863312287006871, 216.96105123, 32.85843364, 1, '205',  7, 1.69242896, 0.36363636, 0.36245253, 1.        ,  3.9206953, 16.545471, 47.05639 , 96.634056, 70.364136, 0.88687035,  0.26674981,  0.9431691 , 0.49405026, 1.31280885, 0.74453106, -0.35157895, -0.25457895, -21.46313876, 0.00139727, 0.09561734),
#           (327863312287006915, 217.0511653 , 32.84766314, 2, '208-211',  7, 1.67287318, 1.        , 0.30099888, 1.        ,  4.7546234, 18.697203, 42.036736, 61.6634  , 40.48283 , 0.9167674 ,  0.17254856,  0.74243163, 0.39930632, 1.12294222, 0.76301457, -0.29196892, -0.19496892, -21.0340388 , 0.00371325, 0.03826194),
#           ...,
#           (327863846674893525, 270.35441696, 67.69966465, 2, '420-426', 15, 1.69747202, 0.8       , 0.3065449 , 1.        ,  7.2226954, 16.78204 , 30.229235, 42.121998, 35.764145, 0.49718757, -0.05002445,  0.36815129, 0.14875532, 0.59677131, 0.46734732, -0.29734855, -0.20034855, -20.73978815, 0.00371325, 0.03826194),
#           (327863846674893695, 270.49522245, 67.63128521, 2, '420-423', 15, 1.63915203, 0.9375    , 0.08391646, 1.        , 11.569131 , 22.080448, 37.162697,  1.55947 , -9.304597, 0.72721406, -0.12006172, -0.14550881, 0.10517793, 0.16568085, 0.64126404, -0.08139897,  0.01560103, -17.87411809, 0.04785387, 0.00307757),
#           (327863846674893766, 270.4453921 , 67.63997844, 2, '423-426', 15, 1.64422256, 1.        , 0.33633892, 1.        ,  8.972751 , 28.1962  , 57.22137 , 95.50403 , 76.459465, 0.70698308,  0.10760349,  0.64378257, 0.33146349, 0.94747601, 0.62714964, -0.32624875, -0.22924875, -21.69373617, 0.0020033 , 0.06867818)],
#          dtype=(numpy.record, [('TARGETID', '>i8'), ('RA', '>f8'), ('DEC', '>f8'), ('NTILE', '>i8'), ('TILES', 'S43'), ('ROSETTE_NUMBER', '>i4'), ('ROSETTE_R', '>f8'), ('COMP_TILE', '>f8'), ('Z', '>f8'), ('WEIGHT', '>f8'), ('FLUX_G_DERED', '>f4'), ('FLUX_R_DERED', '>f4'), ('FLUX_Z_DERED', '>f4'), ('FLUX_W1_DERED', '>f4'), ('FLUX_W2_DERED', '>f4'), ('REST_GMR_0P1', '>f8'), ('KCORR_R0P1', '>f8'), ('KCORR_G0P1', '>f8'), ('KCORR_R0P0', '>f8'), ('KCORR_G0P0', '>f8'), ('REST_GMR_0P0', '>f8'), ('EQ_ALL_0P0', '>f8'), ('EQ_ALL_0P1', '>f8'), ('ABSMAG_R', '>f8'), ('NZ', '>f8'), ('WEIGHT_FKP', '>f8')]))

# %%
np.shape(data)
# Out:
# (215721,)

# %% [markdown]
# ### Necesito 3 coordenadas -> tengo RA, DEC, Z

# %%
data.columns #! Que es formato K y 43A?
# Out:
# ColDefs(
#     name = 'TARGETID'; format = 'K'
#     name = 'RA'; format = 'D'; unit = 'deg'
#     name = 'DEC'; format = 'D'; unit = 'deg'
#     name = 'NTILE'; format = 'K'
#     name = 'TILES'; format = '43A'
#     name = 'ROSETTE_NUMBER'; format = 'J'
#     name = 'ROSETTE_R'; format = 'D'; unit = 'deg'
#     name = 'COMP_TILE'; format = 'D'
#     name = 'Z'; format = 'D'
#     name = 'WEIGHT'; format = 'D'
#     name = 'FLUX_G_DERED'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_R_DERED'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_Z_DERED'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W1_DERED'; format = 'E'; unit = 'nanomaggy'
#     name = 'FLUX_W2_DERED'; format = 'E'; unit = 'nanomaggy'
#     name = 'REST_GMR_0P1'; format = 'D'
#     name = 'KCORR_R0P1'; format = 'D'
#     name = 'KCORR_G0P1'; format = 'D'
#     name = 'KCORR_R0P0'; format = 'D'
#     name = 'KCORR_G0P0'; format = 'D'
#     name = 'REST_GMR_0P0'; format = 'D'
#     name = 'EQ_ALL_0P0'; format = 'D'
#     name = 'EQ_ALL_0P1'; format = 'D'
#     name = 'ABSMAG_R'; format = 'D'
#     name = 'NZ'; format = 'D'; unit = 'h^3 Mpc^-3'
#     name = 'WEIGHT_FKP'; format = 'D'
# )

# %% [markdown]
# ### Formatos
#
# 'A': Cadena de caracteres (texto).
#
# 'I': Número entero con signo (entero).
#
# 'J': Número entero largo con signo (entero largo).
#
# 'E': Número en notación científica de precisión simple.
#
# 'D': Número de punto flotante de doble precisión.
#
# 'L': Valor lógico (verdadero o falso).

# %%
table['Z']
# Out:
# <Column name='Z' dtype='float64' length=215721>
#  0.18115679145762623
#   0.3624525260132444
#   0.3009988823837262
#    0.269749437606277
#  0.38642550584480345
#  0.05474407320670259
# 0.040109717978985916
#  0.10301862103966075
#  0.14433940320340033
#   0.2776172835715325
#  0.21679937117998668
#   0.3095642770432866
#                  ...
#   0.1950220098300637
#  0.02789546794271937
#  0.11205088047377179
#  0.12456515798915681
#   0.1553001208749083
#  0.35646328259420346
#  0.34221753691430223
#   0.2736930796541994
#   0.1390158229128644
#  0.30654489760723264
#  0.08391646346574479
#   0.3363389217108942

# %%
max(table['Z']) #! Z<0.6
# Out:
# 0.59899602949955

# %%
d = cosmo.comoving_distance(table['Z'])
d
# Out:
# <Quantity [ 751.88840166, 1438.77437216, 1213.3743285 , ..., 1234.02821237,
#             356.25333197, 1343.92264421] Mpc>

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_title('')

ax.set_xlabel('RA (°)')
ax.set_ylabel('DEC (°)')
ax.set_zlabel('d (Mpc)')

ax.scatter(table['RA'], table['DEC'], d, s=0.01)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_title('')

ax.set_xlabel('RA (°)')
ax.set_ylabel('DEC (°)')
ax.set_zlabel('d (Mpc)')

ax.scatter(table['RA'], table['DEC'], c=d, cmap='viridis')
ax.set_title('Rosette n')
# Out:
# Text(0.5, 0.92, 'Rosette n')

# %%
hdu.close()

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# ## BGS clustering

# %%
with fits.open('./data/BGS_BRIGHT_N_0_clustering.ran.fits') as hdu:
    table = t(hdu[1].data)

table
# Out:
# <Table length=215721>
#      TARGETID              RA         ...       WEIGHT_FKP
#       int64             float64       ...        float64
# ------------------ ------------------ ... ---------------------
# 327863312287006861   217.053993747975 ...   0.01149153305805754
# 327863312287006871 216.96105123277434 ...   0.09561734123289738
# 327863312287006915 217.05116530360402 ...   0.03826194249707034
# 327863312287006987  217.0442969494446 ...  0.017459485623234086
# 327863312287007608 217.05123979169434 ...   0.13371119385114222
# 327863312287007688 216.98216862256743 ... 0.0029186997834375608
# 327863312287007980 216.99280256908355 ... 0.0017445635962380836
# 327863312287008123  217.0097205677191 ...  0.007066106315277897
# 327863312287008353  217.0434195828927 ...  0.005921525235303553
# 327863312287008359 216.94778732912923 ...  0.035160847734210195
#                ...                ... ...                   ...
# 327863846674892879 270.45760404158284 ...  0.007104943156241312
# 327863846674892907  270.5202206214184 ...  0.007104943156241312
# 327863846674893037  270.6329155217185 ...    0.0122182687745007
# 327863846674893315  270.6540766049186 ...   0.09561734123289738
# 327863846674893321  270.6467010968857 ...   0.06867818347743217
# 327863846674893364  270.6784787549827 ...  0.035160847734210195
# 327863846674893425  270.4423925352603 ...  0.005921525235303553
# 327863846674893525  270.3544169603379 ...   0.03826194249707034
# 327863846674893695  270.4952224471177 ... 0.0030775738791196166
# 327863846674893766  270.4453921010364 ...   0.06867818347743217

# %%
hdu = fits.open('./data/BGS_ANY_N_clustering.dat.fits')
data_bgs = hdu[1].data
t(data_bgs)
# Out:
# <Table length=113691>
#         RA                DEC         ...      WEIGHT_FKP
#      float64            float64       ...       float64
# ------------------ ------------------ ... --------------------
# 191.14757099005186    60.345815959235 ...   0.0189012692383565
# 187.05117249536465 62.614542270156655 ...   0.0189012692383565
# 187.83760708675698  60.38987543677365 ... 0.008223843310435642
#  188.7298325265811 60.181046704454054 ...   0.0189012692383565
# 187.04622815471808  60.82670180284912 ... 0.055734255355941044
# 189.28672536137475  60.18713259808659 ... 0.010340274472459292
#  188.7327720032468 60.217374759371836 ... 0.011002985286624948
# 189.20703625254848  60.13450219401336 ... 0.008223843310435642
# 186.48359894373857  61.73967570511937 ... 0.002739038688499766
# 186.61774077015875 61.718309619882255 ... 0.025652801612254514
#                ...                ... ...                  ...
# 187.25909848754628  62.93333709890637 ... 0.010097411828635255
# 187.25692219655429 62.913345534917596 ...  0.06793306689425052
#  186.7389097143274 62.415513625102626 ... 0.004728276988052915
#  187.0795267943217 62.817396818998986 ... 0.004728276988052915
# 187.25534832226398  62.91755906787288 ... 0.004728276988052915
# 186.62663774704203  62.14939260669518 ... 0.010097411828635255
# 186.61056945797014  62.14298927804953 ... 0.008223843310435642
# 186.60265136574742  62.00944823146277 ... 0.010097411828635255
# 186.56272095205998  62.16469918941913 ... 0.010097411828635255
# 192.89680389488623  62.39132247109831 ...   0.1468791809858338

# %%
n_r = np.unique(data_bgs['ROSETTE_NUMBER'])
n_r
# Out:
# array([ 3,  6,  7, 11, 12, 13, 14, 15, 18, 19], dtype=int32)

# %%
rosette_n = data_bgs[data_bgs['ROSETTE_NUMBER'] == 3]
rosette_n
# Out:
# FITS_rec([(191.14757099, 60.34581596, 39633390185480938, 1, '100', 0.28194599, 0.43181818, 3, 1.57434909, 0.33333333, [-8790991219464744880, -4387867067969646830], 0.3203125, 1., 3.07142857,  6.782468 , 16.732075, 29.996437, 31.939342, 25.343126, 0.60310555, -0.00070293, 0.37659733, 0.21603985, 0.64180908, 0.55463657, -0.27348761, -0.17648761, -20.5772533 , 0.00768781, 0.01890127),
#           (187.0511725 , 62.61454227, 39633416324383107, 1, '100', 0.27035793, 0.43181818, 3, 1.55798544, 1.        , [                  -1,                   -1], 1.       , 1., 1.        ,  4.4575434, 17.798513, 37.420948, 46.075268, 30.963612, 0.99617708,  0.14640987, 0.6534524 , 0.37973343, 1.05020452, 0.83274851, -0.26224719, -0.16524719, -20.68730214, 0.00768781, 0.01890127),
#           (187.83760709, 60.38987544, 39633393155049303, 1, '100', 0.17311082, 0.43181818, 3, 1.72672824, 0.2       , [-6539912815536352385,  9025372152329235987], 0.546875 , 1., 1.81690141, 13.26433  , 27.728409, 46.020153, 37.03337 , 25.867756, 0.65954632, -0.04866412, 0.09238962, 0.17196093, 0.37850624, 0.59405475, -0.16791749, -0.07091749, -19.88791208, 0.01786157, 0.00822384),
#           ...,
#           (186.60265137, 62.00944823, 39633410666268292, 2, '99-102', 0.26670084, 0.64444444, 3, 1.56673691, 1.        , [                  -1,                   -1], 1.       , 1., 1.        ,  6.8776193, 15.315929, 24.66735 , 19.80414 , 14.989974, 0.53322441, -0.04546885, 0.29056944, 0.15942254, 0.53163919, 0.49704604, -0.25869981, -0.16169981, -20.29859943, 0.01451989, 0.01009741),
#           (186.56272095, 62.16469919, 39633413505811644, 2, '99-102', 0.25371984, 0.64444444, 3, 1.60932974, 1.        , [                  -1,                   -1], 1.       , 1., 1.        ,  6.9922595, 25.884378, 52.148464, 56.06758 , 39.11194 , 0.96504642,  0.1129776 , 0.5689822 , 0.34290648, 0.960662  , 0.8032955 , -0.24610825, -0.14910825, -20.903541  , 0.01451989, 0.01009741),
#           (192.89680389, 62.39132247, 39633416366328637, 2, '99-103', 0.46061766, 1.        , 3, 1.52187336, 1.        , [                  -1,                   -1], 1.       , 1., 1.        ,  6.016646 , 23.444977, 54.410477, 81.23976 , 47.22951 , 0.79669428,  0.42470205, 1.10474574, 0.65363938, 1.44159661, 0.68878075, -0.44679913, -0.34979913, -22.61272773, 0.00086026, 0.14687918)],
#          dtype=(numpy.record, [('RA', '>f8'), ('DEC', '>f8'), ('TARGETID', '>i8'), ('NTILE', '>i8'), ('TILES', 'S43'), ('Z', '>f8'), ('COMP_TILE', '>f8'), ('ROSETTE_NUMBER', '>i4'), ('ROSETTE_R', '>f8'), ('FRACZ_TILELOCID', '>f8'), ('BITWEIGHTS', '>i8', (2,)), ('PROB_OBS', '>f8'), ('WEIGHT_ZFAIL', '>f8'), ('WEIGHT', '>f8'), ('FLUX_G_DERED', '>f4'), ('FLUX_R_DERED', '>f4'), ('FLUX_Z_DERED', '>f4'), ('FLUX_W1_DERED', '>f4'), ('FLUX_W2_DERED', '>f4'), ('REST_GMR_0P1', '>f8'), ('KCORR_R0P1', '>f8'), ('KCORR_G0P1', '>f8'), ('KCORR_R0P0', '>f8'), ('KCORR_G0P0', '>f8'), ('REST_GMR_0P0', '>f8'), ('EQ_ALL_0P0', '>f8'), ('EQ_ALL_0P1', '>f8'), ('ABSMAG_R', '>f8'), ('NZ', '>f8'), ('WEIGHT_FKP', '>f8')]))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

d = cosmo.comoving_distance(rosette_n['Z'])

ax.set_xlabel('RA')
ax.set_ylabel('DEC')
ax.set_zlabel('d')

ax.scatter(rosette_n['RA'], rosette_n['DEC'], c=d, s=1, cmap='viridis')
ax.set_title('Rosette 3')
# Out:
# Text(0.5, 0.92, 'Rosette 3')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

rosette_3 = data_bgs[data_bgs['ROSETTE_NUMBER'] == 3]
d3 = cosmo.comoving_distance(rosette_3['Z'])

ax.set_xlabel('RA')
ax.set_ylabel('DEC')

ax.scatter(rosette_3['RA'], rosette_3['DEC'], s=0.8)
ax.set_title('Rosette 3')
# Out:
# Text(0.5, 1.0, 'Rosette 3')

# %%
t(rosette_n)
# Out:
# <Table length=11313>
#         RA                DEC         ...      WEIGHT_FKP
#      float64            float64       ...       float64
# ------------------ ------------------ ... --------------------
# 191.14757099005186    60.345815959235 ...   0.0189012692383565
# 187.05117249536465 62.614542270156655 ...   0.0189012692383565
# 187.83760708675698  60.38987543677365 ... 0.008223843310435642
#  188.7298325265811 60.181046704454054 ...   0.0189012692383565
# 187.04622815471808  60.82670180284912 ... 0.055734255355941044
# 189.28672536137475  60.18713259808659 ... 0.010340274472459292
#  188.7327720032468 60.217374759371836 ... 0.011002985286624948
# 189.20703625254848  60.13450219401336 ... 0.008223843310435642
# 186.48359894373857  61.73967570511937 ... 0.002739038688499766
# 186.61774077015875 61.718309619882255 ... 0.025652801612254514
#                ...                ... ...                  ...
# 187.25909848754628  62.93333709890637 ... 0.010097411828635255
# 187.25692219655429 62.913345534917596 ...  0.06793306689425052
#  186.7389097143274 62.415513625102626 ... 0.004728276988052915
#  187.0795267943217 62.817396818998986 ... 0.004728276988052915
# 187.25534832226398  62.91755906787288 ... 0.004728276988052915
# 186.62663774704203  62.14939260669518 ... 0.010097411828635255
# 186.61056945797014  62.14298927804953 ... 0.008223843310435642
# 186.60265136574742  62.00944823146277 ... 0.010097411828635255
# 186.56272095205998  62.16469918941913 ... 0.010097411828635255
# 192.89680389488623  62.39132247109831 ...   0.1468791809858338

# %%
id = rosette_n['TARGETID']
id
# Out:
# array([39633390185480938, 39633416324383107, 39633393155049303, ...,
#        39633410666268292, 39633413505811644, 39633416366328637])

# %% [markdown]
# ## Probabilistic Value-Added

# %%
data_prova = misc.hdf5.read_table_hdf5('./data/BGS_ANY_full.provabgs.sv3.v0.hdf5')
data_prova #! PROVABGS_LOGMSTAR_BF
# Out:
# <Table length=264973>
#      TARGETID             RA         ... IS_BGS_BRIGHT IS_BGS_FAINT
#       int64            float64       ...      bool         bool
# ----------------- ------------------ ... ------------- ------------
# 39633390185481181 191.17913199949842 ...         False        False
# 39633390164510024  188.6998080571996 ...         False        False
# 39633390185480955 191.14955067198017 ...         False        False
# 39633390185480938 191.14757099005186 ...          True        False
# 39633416324383107 187.05117249536465 ...          True        False
# 39633393155049062  187.8080794399063 ...         False        False
# 39633393155049303 187.83760708675698 ...          True        False
# 39633393155049428  187.8512261193913 ...         False        False
# 39633390164510257  188.7298325265811 ...          True        False
# 39633390164510424  188.7466620059061 ...         False        False
#               ...                ... ...           ...          ...
# 39633419117789446  187.0795267943217 ...          True        False
# 39633421890224923 187.25534832226398 ...          True        False
# 39633413505812174 186.62663774704203 ...          True        False
# 39633413505812049 186.61056945797014 ...          True        False
# 39633410666268292 186.60265136574742 ...          True        False
# 39633413505812025 186.60738127477714 ...         False        False
# 39633413505811874   186.589245124884 ...         False        False
# 39633413505811644 186.56272095205998 ...          True        False
# 39633419117789555   187.095748149906 ...         False        False
# 39633416366328637 192.89680389488623 ...          True        False

# %%
data_prova.info()
# Out:
# <Table length=264973>
#         name          dtype    shape   n_bad
# -------------------- ------- --------- -----
#             TARGETID   int64               0
#                   RA float64               0
#                  DEC float64               0
#                 Z_HP float64               0
#                 ZERR float64           16626
#            TSNR2_BGS float32               0
#                MAG_G float64               0
#                MAG_R float64               0
#                MAG_Z float64               0
#               MAG_W1 float64               0
#             FIBMAG_R float64               0
#              HPIX_64   int64               0
#        PROVABGS_MCMC float64 (100, 13)     0
#    PROVABGS_THETA_BF float64     (13,)     0
#       PROVABGS_Z_MAX float64               0
# PROVABGS_LOGMSTAR_BF float64               0
#    PROVABGS_LOGMSTAR float64    (100,)     0
#       SCHLEGEL_COLOR float64               0
#     PROVABGS_W_ZFAIL float64               0
# PROVABGS_W_FIBASSIGN float64               0
#        IS_BGS_BRIGHT    bool               0
#         IS_BGS_FAINT    bool               0

# %% [markdown]
# ----
# ### hpy5

# %%
data_prova = h5py.File('./data/BGS_ANY_full.provabgs.sv3.v0.hdf5')
data_prova
# Out:
# <HDF5 file "BGS_ANY_full.provabgs.sv3.v0.hdf5" (mode r)>

# %%
list(data_prova.keys())
# Out:
# ['__astropy_table__']

# %%
dataset = data_prova['__astropy_table__']
dataset.dtype
# Out:
# dtype([('TARGETID', '<i8'), ('RA', '<f8'), ('DEC', '<f8'), ('Z_HP', '<f8'), ('ZERR', '<f8'), ('TSNR2_BGS', '<f4'), ('MAG_G', '<f8'), ('MAG_R', '<f8'), ('MAG_Z', '<f8'), ('MAG_W1', '<f8'), ('FIBMAG_R', '<f8'), ('HPIX_64', '<i8'), ('PROVABGS_MCMC', '<f8', (100, 13)), ('PROVABGS_THETA_BF', '<f8', (13,)), ('PROVABGS_Z_MAX', '<f8'), ('PROVABGS_LOGMSTAR_BF', '<f8'), ('PROVABGS_LOGMSTAR', '<f8', (100,)), ('SCHLEGEL_COLOR', '<f8'), ('PROVABGS_W_ZFAIL', '<f8'), ('PROVABGS_W_FIBASSIGN', '<f8'), ('IS_BGS_BRIGHT', '?'), ('IS_BGS_FAINT', '?')])

# %%
selected = []

for n in range(0, np.size(dataset)): #! t ~10min
    if dataset[n][0] in id:
        selected.append((dataset[n][0], dataset[n][15]))

# %%
selected = []

for n in range(0, 1000):
    if dataset[n][0] in id:
        selected.append((dataset[n][0], dataset[n][15]))

# %%
selected = np.array(selected)
np.size(id), np.size(selected)

#np.size(np.unique(id)) #! repetidos???
# Out:
# (11313, 254)

# %%
mass = selected
node_info = []
edge_info = []

for j in range(0, len(mass)):
    data_j = data_bgs[data_bgs['TARGETID'] == mass[j][0]]

    flux_g = data_j['FLUX_G_DERED'][0]
    flux_r = data_j['FLUX_R_DERED'][0]
    flux_z = data_j['FLUX_Z_DERED'][0]
    flux_w1 = data_j['FLUX_W1_DERED'][0]
    flux_w2 = data_j['FLUX_W2_DERED'][0]
    node_info.append([mass[j][0], [mass[j][1],flux_g,flux_r,flux_z,flux_w1,flux_w2]])

    d_n = cosmo.comoving_distance(data_j['Z'])
    edge_info.append([mass[j][0], d_n])

# %%
edge_info
# Out:
# [[3.9633390185480936e+16, <Quantity [1141.94632154] Mpc>],
#  [3.96334163243831e+16, <Quantity [1098.14464909] Mpc>],
#  [3.9633393155049304e+16, <Quantity [719.86728767] Mpc>],
#  [3.963339016451026e+16, <Quantity [1155.0178941] Mpc>],
#  [3.9633396124617896e+16, <Quantity [1480.29872873] Mpc>],
#  [3.963339016870473e+16, <Quantity [883.28843686] Mpc>],
#  [3.963339016451028e+16, <Quantity [954.41014908] Mpc>],
#  [3.963339016870421e+16, <Quantity [764.25290169] Mpc>],
#  [3.963340780155832e+16, <Quantity [364.00361509] Mpc>],
#  [3.96334078015593e+16, <Quantity [1259.44862518] Mpc>],
#  [3.963338714461233e+16, <Quantity [1659.96241643] Mpc>],
#  [3.963338714880503e+16, <Quantity [1467.85488489] Mpc>],
#  [3.963338714880581e+16, <Quantity [890.10222087] Mpc>],
#  [3.963339018548134e+16, <Quantity [380.2760493] Mpc>],
#  [3.963339015612285e+16, <Quantity [1372.92429134] Mpc>],
#  [3.963339015612341e+16, <Quantity [528.24462431] Mpc>],
#  [3.963339016031702e+16, <Quantity [441.97470733] Mpc>],
#  [3.963339016031785e+16, <Quantity [1243.34098694] Mpc>],
#  [3.963339018548116e+16, <Quantity [1302.52749542] Mpc>],
#  [3.963341350581391e+16, <Quantity [518.8320732] Mpc>],
#  [3.963339016870396e+16, <Quantity [961.4501565] Mpc>],
#  [3.963339315085644e+16, <Quantity [976.9504473] Mpc>],
#  [3.9633402009226456e+16, <Quantity [1489.86528464] Mpc>],
#  [3.963339315924224e+16, <Quantity [1125.56665911, 1245.60204263] Mpc>],
#  [3.963339016450882e+16, <Quantity [427.72660275] Mpc>],
#  [3.963339016450928e+16, <Quantity [1174.4216603] Mpc>],
#  [3.963339016451019e+16, <Quantity [1661.6833391] Mpc>],
#  [3.963339018548094e+16, <Quantity [1353.88272635] Mpc>],
#  [3.9633399127738904e+16, <Quantity [939.93833105] Mpc>],
#  [3.963339018548269e+16, <Quantity [2025.46482171] Mpc>],
#  [3.963338714880662e+16, <Quantity [440.3107088] Mpc>],
#  [3.96333871488066e+16, <Quantity [959.63082716] Mpc>],
#  [3.963339016451035e+16, <Quantity [1657.84793041] Mpc>],
#  [3.9633390185481e+16, <Quantity [1144.45932833] Mpc>],
#  [3.963339017709444e+16, <Quantity [960.66875589] Mpc>],
#  [3.9633410720792776e+16, <Quantity [1511.77126814] Mpc>],
#  [3.9633410720793544e+16, <Quantity [1511.64797985] Mpc>],
#  [3.96334107207936e+16, <Quantity [452.77259487] Mpc>],
#  [3.963341072079376e+16, <Quantity [1854.07877661] Mpc>],
#  [3.9633404970404616e+16, <Quantity [778.27659367] Mpc>],
#  [3.9633396170754904e+16, <Quantity [988.54049163] Mpc>],
#  [3.963339617075504e+16, <Quantity [452.27105262] Mpc>],
#  [3.963339617494655e+16, <Quantity [518.17961598] Mpc>],
#  [3.9633404970404216e+16, <Quantity [657.85330047] Mpc>],
#  [3.9633404970404024e+16, <Quantity [1061.11720857] Mpc>],
#  [3.963341355614465e+16, <Quantity [797.42737934] Mpc>],
#  [3.963341356033657e+16, <Quantity [432.40724788] Mpc>],
#  [3.963341356033684e+16, <Quantity [447.26001403] Mpc>],
#  [3.9633413560337096e+16, <Quantity [505.98257886] Mpc>],
#  [3.963341355614473e+16, <Quantity [1077.3783458] Mpc>],
#  [3.963342738476429e+16, <Quantity [439.62794355] Mpc>],
#  [3.963341915973383e+16, <Quantity [1196.99138121] Mpc>],
#  [3.963340785608535e+16, <Quantity [660.74425379] Mpc>],
#  [3.963341915973408e+16, <Quantity [1206.75808673] Mpc>],
#  [3.963341915973535e+16, <Quantity [1407.60349502, 1093.93618101] Mpc>],
#  [3.963341915973484e+16, <Quantity [1193.99622018] Mpc>],
#  [3.963341915973492e+16, <Quantity [1728.7942522] Mpc>],
#  [3.963341915973514e+16, <Quantity [1058.00568467] Mpc>],
#  [3.963342193216768e+16, <Quantity [257.362611] Mpc>],
#  [3.963341637052152e+16, <Quantity [616.36888139] Mpc>],
#  [3.963341637052124e+16, <Quantity [1122.65849432] Mpc>],
#  [3.9633416370521896e+16, <Quantity [462.45115658] Mpc>],
#  [3.963341637052194e+16, <Quantity [1336.74246308] Mpc>],
#  [3.963341637052117e+16, <Quantity [614.74574961] Mpc>],
#  [3.9633416370522136e+16, <Quantity [899.35328834] Mpc>],
#  [3.96334163705206e+16, <Quantity [1077.23086012] Mpc>],
#  [3.963342466266216e+16, <Quantity [379.01521771] Mpc>],
#  [3.963341071660102e+16, <Quantity [780.19183219] Mpc>],
#  [3.963339018128818e+16, <Quantity [1324.54913683] Mpc>],
#  [3.963340497040358e+16, <Quantity [1033.84203779] Mpc>],
#  [3.9633404970404e+16, <Quantity [119.00326035] Mpc>],
#  [3.963340497040412e+16, <Quantity [422.81780366] Mpc>],
#  [3.9633413556145176e+16, <Quantity [1913.26344444] Mpc>],
#  [3.963339018128806e+16, <Quantity [1050.54613176, 1162.0344817 ] Mpc>],
#  [3.963341069143519e+16, <Quantity [480.12139332] Mpc>],
#  [3.963340780155827e+16, <Quantity [1046.56763423] Mpc>],
#  [3.9633407801557256e+16, <Quantity [326.03968131] Mpc>],
#  [3.96333961288104e+16, <Quantity [1330.1674189] Mpc>],
#  [3.9633396128810424e+16, <Quantity [991.27332211] Mpc>],
#  [3.963339612881088e+16, <Quantity [520.25956466] Mpc>],
#  [3.963340779736667e+16, <Quantity [326.67995948] Mpc>],
#  [3.963340200922504e+16, <Quantity [1194.79532238] Mpc>],
#  [3.96334020092257e+16, <Quantity [1480.11867166] Mpc>],
#  [3.963340491587668e+16, <Quantity [1698.20498122] Mpc>],
#  [3.963340200922478e+16, <Quantity [933.63089193] Mpc>],
#  [3.963341066207523e+16, <Quantity [1076.42025209] Mpc>],
#  [3.963341066626685e+16, <Quantity [1074.1872571] Mpc>],
#  [3.9633416324383064e+16, <Quantity [1242.04946264] Mpc>],
#  [3.963341066207529e+16, <Quantity [960.75264107] Mpc>],
#  [3.963341632019017e+16, <Quantity [718.62969404, 859.97267924] Mpc>],
#  [3.963341911359717e+16, <Quantity [710.07058261] Mpc>],
#  [3.963341632019017e+16, <Quantity [718.62969404, 859.97267924] Mpc>],
#  [3.9633424645884456e+16, <Quantity [1205.81005533] Mpc>],
#  [3.963342189022667e+16, <Quantity [1074.53289976] Mpc>],
#  [3.963341911778925e+16, <Quantity [1185.39986101] Mpc>],
#  [3.963341911359861e+16, <Quantity [2113.98025928] Mpc>],
#  [3.9633419113598456e+16, <Quantity [1744.20961732] Mpc>],
#  [3.963341911359807e+16, <Quantity [735.58878768] Mpc>],
#  [3.963341911359795e+16, <Quantity [1188.16921227] Mpc>],
#  [3.96334135058136e+16, <Quantity [772.90060021] Mpc>],
#  [3.963341350581316e+16, <Quantity [860.39243811] Mpc>],
#  [3.963341066626712e+16, <Quantity [982.3287781] Mpc>],
#  [3.963341066626725e+16, <Quantity [1165.30729975] Mpc>],
#  [3.96334135058123e+16, <Quantity [667.0402887] Mpc>],
#  [3.963341066626703e+16, <Quantity [797.26293235] Mpc>],
#  [3.963341350581161e+16, <Quantity [666.88557085] Mpc>],
#  [3.9633413505810856e+16, <Quantity [959.54189338] Mpc>],
#  [3.96334163201895e+16, <Quantity [1538.73633754] Mpc>],
#  [3.963341350581208e+16, <Quantity [1191.74971173] Mpc>],
#  [3.963341632018886e+16, <Quantity [704.90333327] Mpc>],
#  [3.963341632018939e+16, <Quantity [719.98176931] Mpc>],
#  [3.96334163201885e+16, <Quantity [626.19477267] Mpc>],
#  [3.96334106620756e+16, <Quantity [799.8231264] Mpc>],
#  [3.9633410662075704e+16, <Quantity [1945.84280316] Mpc>],
#  [3.963339318440866e+16, <Quantity [1366.70176106] Mpc>],
#  [3.9633390164512136e+16, <Quantity [520.00550936] Mpc>],
#  [3.96333901645117e+16, <Quantity [1212.74672335] Mpc>],
#  [3.96333901645121e+16, <Quantity [1636.21710688] Mpc>],
#  [3.963339016870303e+16, <Quantity [949.53969247] Mpc>],
#  [3.9633399131931256e+16, <Quantity [915.07677646] Mpc>],
#  [3.963339319279753e+16, <Quantity [1527.22194709] Mpc>],
#  [3.963339018967661e+16, <Quantity [1418.85751379] Mpc>],
#  [3.9633390181288776e+16, <Quantity [995.77350256] Mpc>],
#  [3.963339319279845e+16, <Quantity [822.64249617] Mpc>],
#  [3.963339018128833e+16, <Quantity [1670.02851471] Mpc>],
#  [3.963339016870319e+16, <Quantity [1659.91834243] Mpc>],
#  [3.963339018967721e+16, <Quantity [823.37045437] Mpc>]]
