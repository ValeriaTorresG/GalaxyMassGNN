# %%
import pandas as pd

# %%
df = pd.read_csv('./data/rosette3_nodes.csv')
df
# Out:
#                TARGET_ID  PROVABGS_LOGMSTAR_BF  FLUX_G_DERED  FLUX_R_DERED  \
# 0      39633390185480938             10.894820      6.782468     16.732075
# 1      39633416324383107             10.909547      4.457543     17.798513
# 2      39633393155049303             10.270718     13.264330     27.728409
# 3      39633390164510257             11.017787      9.799708     23.078470
# 4      39633396124617897             11.287631      4.046807     16.825310
# ...                  ...                   ...           ...           ...
# 11182  39633413505812174             10.608656      6.489779     15.314315
# 11183  39633413505812049             10.127943     19.767212     45.519585
# 11184  39633410666268292             10.643876      6.877619     15.315929
# 11185  39633413505811644             10.684380      6.992260     25.884378
# 11186  39633416366328637             12.271829      6.016646     23.444977
#
#        FLUX_Z_DERED  FLUX_W1_DERED  FLUX_W2_DERED         Z
# ...
